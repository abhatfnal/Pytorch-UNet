# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import os
from matplotlib.backends.backend_pdf import PdfPages  # Import PdfPages for saving to a PDF
import torch

# Import the predict_img function and models from the previous script
from unet import UNet
from utils import hwc_to_chw, h5_utils as h5u

# Path to the folder containing the output files
output_folder = '/exp/sbnd/data/users/abhat/wirecell_data/dnn_roi/ICARUS/81858535_63/'  # Change this to your output folder
pdf_filename = "81858535_63_images.pdf"  # Name of the output PDF should be similar to the last folder path above

# Define TPCs and planes
tpcs=[0,1,2,3]
planes = ['front_induction', 'middle_induction']
plane_suffix_map = {'front_induction': '0', 'middle_induction': '1'}

# Specify which event to plot (index 0 to 9)
event_to_plot = 9  # Change this to the event index you want to plot

# Load U and V Plane models
model_u_path = '/scratch/7DayLifetime/abhat/wirecell/dnn_roi_icarus/training/bnb_cosmics/UNet/U_Plane/best_loss.pth'
model_v_path = '/scratch/7DayLifetime/abhat/wirecell/dnn_roi_icarus/training/bnb_cosmics/UNet/V_Plane/best_loss.pth'

net_u = UNet(2, 1)
net_u.load_state_dict(torch.load(model_u_path, map_location='cpu'))
net_u.eval()

net_v = UNet(2, 1)
net_v.load_state_dict(torch.load(model_v_path, map_location='cpu'))
net_v.eval()


def predict_img(net, full_img, scale_factor=0.5, out_threshold=0.5, use_gpu=False):
    img_tensor = torch.from_numpy(hwc_to_chw(full_img))
    if use_gpu:
        img_tensor = img_tensor.cuda()

    with torch.no_grad():
        input = img_tensor.unsqueeze(0)
        full_mask = net(input).squeeze().cpu().numpy()

    if out_threshold < 0:
        return full_mask

    return full_mask > out_threshold

def model_selection(file_path, plane):
    if plane == "U":
        net = net_u
        img = h5u.get_hwc_img(file_path, event_to_plot, ['frame_looseLf', 'frame_mp3ROI'], [1, 8], [0, 2112], [0, 4096], 2000)
    elif plane == "V":
        net = net_v
        img = h5u.get_hwc_img(file_path, event_to_plot, ['frame_looseLf', 'frame_mp3ROI'], [1, 8], [0, 5600], [0, 4096], 2000)

    # Make the prediction
    predicted_mask = predict_img(net=net, full_img=img, scale_factor=0.5, out_threshold=0.5, use_gpu=False)
    return np.transpose(predicted_mask)

# Define the function to plot the data for each TPC and plane
def plot_data(tpc, plane, plane_suffix, data_dict, event_idx, predicted_image, pdf):
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))  # Adjust grid to fit only 4 images (DepoSplat, LooseLF, MP3 -> MP2, Predicted)
    titles = ["DepoSplat", "LooseLF", "MP3ROI", "Predicted"]

    # Plot DepoSplat, LooseLF, and MP3 as MP2
    for i, (key, data) in enumerate(data_dict.items()):
        if np.any(data) and i < 2:  # Only plot DepoSplat and LooseLF here
            ax = axes[i//2, i%2]
            ax.imshow(data, aspect='auto', cmap="bwr", vmin=-1000, vmax=1000, origin='lower')
            ax.set_title(f"{titles[i]} TPC{tpc} Plane{plane_suffix} (Event {event_idx})")
            ax.set_xlabel("Channels")
            ax.set_ylabel("Ticks")

    # Plot MP3 image in place of MP2
    ax = axes[1, 0]
    ax.imshow(data_dict["MP3ROI"], aspect='auto', cmap="bwr", vmin=-1000, vmax=1000, origin='lower')
    ax.set_title(f"MP3ROI TPC{tpc} Plane{plane_suffix} (Event {event_idx})")
    ax.set_xlabel("Channels")
    ax.set_ylabel("Ticks")

    # Plot the predicted image
    ax = axes[1, 1]  # Place in the next available subplot
    ax.imshow(predicted_image, aspect='auto', cmap="bwr", origin='lower')
    ax.set_title(f"Predicted Image TPC{tpc} Plane{plane_suffix} (Event {event_idx})")
    ax.set_xlabel("Channels")
    ax.set_ylabel("Ticks")

    plt.tight_layout()
    pdf.savefig(fig)  # Save the figure to the PDF
    plt.close()  # Close the figure after saving to avoid displaying it inline

# Inspect each file for each TPC and plane and save all images to a single PDF
with PdfPages(pdf_filename) as pdf:  # Open the PDF file to save the images
    for tpc in tpcs:
        for plane, plane_suffix in plane_suffix_map.items():
            # Construct file paths
            true_file_path = os.path.join(output_folder, f"tpc{tpc}_plane{plane_suffix}_tru.h5")
            rec_file_path = os.path.join(output_folder, f"tpc{tpc}_plane{plane_suffix}_rec.h5")

            if os.path.exists(true_file_path) and os.path.exists(rec_file_path):
                print(f"Opening files for TPC {tpc}, Plane {plane}:")
                print(f"True file: {true_file_path}")
                print(f"Reconstructed file: {rec_file_path}")

                # Open the files
                with h5py.File(true_file_path, 'r') as true_file, h5py.File(rec_file_path, 'r') as rec_file:
                    # Ensure the event_to_plot exists in the file
                    events = list(true_file.keys())
                    if 0 <= event_to_plot < len(events):
                        event = events[event_to_plot]
                        print(f"Processing event {event} for TPC {tpc}, Plane {plane}...")

                        # Load data for the specified event
                        true_data = true_file[event]['frame_deposplat'][:]
                        rec_data_looseLf = rec_file[event]['frame_looseLf'][:]
                        rec_data_mp3 = rec_file[event]['frame_mp3ROI'][:]  # Using MP3 in place of MP2

                        # Prepare data to plot (no MP2, MP3 in place)
                        data_dict = {
                            "DepoSplat": true_data,
                            "LooseLF": rec_data_looseLf,
                            "MP3ROI": rec_data_mp3
                        }

                        # Generate the predicted image
                        predicted_image = model_selection(rec_file_path, "U" if plane_suffix == "0" else "V")

                        # Plot the data for the specified event and predicted image, and save to the PDF
                        plot_data(tpc, plane, plane_suffix, data_dict, event_to_plot, predicted_image, pdf)
                    else:
                        print(f"Event index {event_to_plot} is out of range for TPC {tpc}, Plane {plane}.")

            else:
                print(f"Files for TPC {tpc}, Plane {plane} not found.")

print(f"All images have been saved to {pdf_filename}.")
# Out:
# Opening files for TPC 0, Plane front_induction:
# True file: /exp/sbnd/data/users/abhat/wirecell_data/dnn_roi/ICARUS/81858535_63/tpc0_plane0_tru.h5
# Reconstructed file: /exp/sbnd/data/users/abhat/wirecell_data/dnn_roi/ICARUS/81858535_63/tpc0_plane0_rec.h5
# Processing event 9 for TPC 0, Plane front_induction...
# Opening files for TPC 0, Plane middle_induction:
# True file: /exp/sbnd/data/users/abhat/wirecell_data/dnn_roi/ICARUS/81858535_63/tpc0_plane1_tru.h5
# Reconstructed file: /exp/sbnd/data/users/abhat/wirecell_data/dnn_roi/ICARUS/81858535_63/tpc0_plane1_rec.h5
# Processing event 9 for TPC 0, Plane middle_induction...
# Opening files for TPC 1, Plane front_induction:
# True file: /exp/sbnd/data/users/abhat/wirecell_data/dnn_roi/ICARUS/81858535_63/tpc1_plane0_tru.h5
# Reconstructed file: /exp/sbnd/data/users/abhat/wirecell_data/dnn_roi/ICARUS/81858535_63/tpc1_plane0_rec.h5
# Processing event 9 for TPC 1, Plane front_induction...
# Opening files for TPC 1, Plane middle_induction:
# True file: /exp/sbnd/data/users/abhat/wirecell_data/dnn_roi/ICARUS/81858535_63/tpc1_plane1_tru.h5
# Reconstructed file: /exp/sbnd/data/users/abhat/wirecell_data/dnn_roi/ICARUS/81858535_63/tpc1_plane1_rec.h5
# Processing event 9 for TPC 1, Plane middle_induction...
# Opening files for TPC 2, Plane front_induction:
# True file: /exp/sbnd/data/users/abhat/wirecell_data/dnn_roi/ICARUS/81858535_63/tpc2_plane0_tru.h5
# Reconstructed file: /exp/sbnd/data/users/abhat/wirecell_data/dnn_roi/ICARUS/81858535_63/tpc2_plane0_rec.h5
# Processing event 9 for TPC 2, Plane front_induction...
# Opening files for TPC 2, Plane middle_induction:
# True file: /exp/sbnd/data/users/abhat/wirecell_data/dnn_roi/ICARUS/81858535_63/tpc2_plane1_tru.h5
# Reconstructed file: /exp/sbnd/data/users/abhat/wirecell_data/dnn_roi/ICARUS/81858535_63/tpc2_plane1_rec.h5
# Processing event 9 for TPC 2, Plane middle_induction...
# Opening files for TPC 3, Plane front_induction:
# True file: /exp/sbnd/data/users/abhat/wirecell_data/dnn_roi/ICARUS/81858535_63/tpc3_plane0_tru.h5
# Reconstructed file: /exp/sbnd/data/users/abhat/wirecell_data/dnn_roi/ICARUS/81858535_63/tpc3_plane0_rec.h5
# Processing event 9 for TPC 3, Plane front_induction...
# Opening files for TPC 3, Plane middle_induction:
# True file: /exp/sbnd/data/users/abhat/wirecell_data/dnn_roi/ICARUS/81858535_63/tpc3_plane1_tru.h5
# Reconstructed file: /exp/sbnd/data/users/abhat/wirecell_data/dnn_roi/ICARUS/81858535_63/tpc3_plane1_rec.h5
# Processing event 9 for TPC 3, Plane middle_induction...
# All images have been saved to 81858535_63_images.pdf.

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import os
from matplotlib.backends.backend_pdf import PdfPages  # Import PdfPages for saving to a PDF
import torch

# Import the predict_img function and models from the previous script
from unet import UNet
from utils import hwc_to_chw, h5_utils as h5u

# Path to the main folder containing subdirectories
main_folder = '/exp/sbnd/data/users/abhat/wirecell_data/dnn_roi/ICARUS/'

# Define TPCs and planes
tpcs = [0, 1, 2, 3]
planes = ['front_induction', 'middle_induction']
plane_suffix_map = {'front_induction': '0', 'middle_induction': '1'}

# Specify which event to plot (index 0 to 9)
event_to_plot = 9  # Change this to the event index you want to plot

# Load U and V Plane models
model_u_path = '/scratch/7DayLifetime/abhat/wirecell/dnn_roi_icarus/training/bnb_cosmics/UNet/U_Plane/best_loss.pth'
model_v_path = '/scratch/7DayLifetime/abhat/wirecell/dnn_roi_icarus/training/bnb_cosmics/UNet/V_Plane/best_loss.pth'

net_u = UNet(2, 1)
net_u.load_state_dict(torch.load(model_u_path, map_location='cpu'))
net_u.eval()

net_v = UNet(2, 1)
net_v.load_state_dict(torch.load(model_v_path, map_location='cpu'))
net_v.eval()

def predict_img(net, full_img, scale_factor=0.5, out_threshold=0.5, use_gpu=False):
    img_tensor = torch.from_numpy(hwc_to_chw(full_img))
    if use_gpu:
        img_tensor = img_tensor.cuda()

    with torch.no_grad():
        input = img_tensor.unsqueeze(0)
        full_mask = net(input).squeeze().cpu().numpy()

    if out_threshold < 0:
        return full_mask

    return full_mask > out_threshold

def model_selection(file_path, plane):
    if plane == "U":
        net = net_u
        img = h5u.get_hwc_img(file_path, event_to_plot, ['frame_looseLf', 'frame_mp3ROI'], [1, 8], [0, 2112], [0, 4096], 2000)
    elif plane == "V":
        net = net_v
        img = h5u.get_hwc_img(file_path, event_to_plot, ['frame_looseLf', 'frame_mp3ROI'], [1, 8], [0, 5600], [0, 4096], 2000)

    predicted_mask = predict_img(net=net, full_img=img, scale_factor=0.5, out_threshold=0.5, use_gpu=False)
    return np.transpose(predicted_mask)

def plot_data(tpc, plane, plane_suffix, data_dict, event_idx, predicted_image, pdf):
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    titles = ["DepoSplat", "LooseLF", "MP3ROI", "Predicted"]

    for i, (key, data) in enumerate(data_dict.items()):
        if np.any(data) and i < 2:
            ax = axes[i//2, i%2]
            ax.imshow(data, aspect='auto', cmap="bwr", vmin=-1000, vmax=1000, origin='lower')
            ax.set_title(f"{titles[i]} TPC{tpc} Plane{plane_suffix} (Event {event_idx})")
            ax.set_xlabel("Channels")
            ax.set_ylabel("Ticks")

    ax = axes[1, 0]
    ax.imshow(data_dict["MP3ROI"], aspect='auto', cmap="bwr", vmin=-1000, vmax=1000, origin='lower')
    ax.set_title(f"MP3ROI TPC{tpc} Plane{plane_suffix} (Event {event_idx})")
    ax.set_xlabel("Channels")
    ax.set_ylabel("Ticks")

    ax = axes[1, 1]
    ax.imshow(predicted_image, aspect='auto', cmap="bwr", origin='lower')
    ax.set_title(f"Predicted Image TPC{tpc} Plane{plane_suffix} (Event {event_idx})")
    ax.set_xlabel("Channels")
    ax.set_ylabel("Ticks")

    plt.tight_layout()
    pdf.savefig(fig)
    plt.close()

# Iterate through all subdirectories in the main folder
with PdfPages("ICARUS_images.pdf") as pdf:
    for folder_name in os.listdir(main_folder):
        folder_path = os.path.join(main_folder, folder_name)
        if os.path.isdir(folder_path):  # Ensure it's a directory
            for tpc in tpcs:
                for plane, plane_suffix in plane_suffix_map.items():
                    true_file_path = os.path.join(folder_path, f"tpc{tpc}_plane{plane_suffix}_tru.h5")
                    rec_file_path = os.path.join(folder_path, f"tpc{tpc}_plane{plane_suffix}_rec.h5")

                    if os.path.exists(true_file_path) and os.path.exists(rec_file_path):
                        print(f"Processing TPC {tpc}, Plane {plane} in folder {folder_name}")

                        with h5py.File(true_file_path, 'r') as true_file, h5py.File(rec_file_path, 'r') as rec_file:
                            events = list(true_file.keys())
                            if 0 <= event_to_plot < len(events):
                                event = events[event_to_plot]

                                true_data = true_file[event]['frame_deposplat'][:]
                                rec_data_looseLf = rec_file[event]['frame_looseLf'][:]
                                rec_data_mp3 = rec_file[event]['frame_mp3ROI'][:]

                                data_dict = {
                                    "DepoSplat": true_data,
                                    "LooseLF": rec_data_looseLf,
                                    "MP3ROI": rec_data_mp3
                                }

                                predicted_image = model_selection(rec_file_path, "U" if plane_suffix == "0" else "V")

                                plot_data(tpc, plane, plane_suffix, data_dict, event_to_plot, predicted_image, pdf)
                            else:
                                print(f"Event index {event_to_plot} is out of range for TPC {tpc}, Plane {plane}.")
                    else:
                        print(f"Files for TPC {tpc}, Plane {plane} not found in folder {folder_name}.")

print("All images have been saved to a single PDF.")
# Out:
# Processing TPC 0, Plane front_induction in folder 81858535_74
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# Processing TPC 0, Plane middle_induction in folder 81858535_74
# Processing TPC 1, Plane front_induction in folder 81858535_74
# Processing TPC 1, Plane middle_induction in folder 81858535_74
# Processing TPC 2, Plane front_induction in folder 81858535_74
# Processing TPC 2, Plane middle_induction in folder 81858535_74
# Processing TPC 3, Plane front_induction in folder 81858535_74
# Processing TPC 3, Plane middle_induction in folder 81858535_74
# Processing TPC 0, Plane front_induction in folder 81858535_72
# Processing TPC 0, Plane middle_induction in folder 81858535_72
# Processing TPC 1, Plane front_induction in folder 81858535_72
# Processing TPC 1, Plane middle_induction in folder 81858535_72
# Processing TPC 2, Plane front_induction in folder 81858535_72
# Processing TPC 2, Plane middle_induction in folder 81858535_72
# Processing TPC 3, Plane front_induction in folder 81858535_72
# Processing TPC 3, Plane middle_induction in folder 81858535_72
# Processing TPC 0, Plane front_induction in folder 81858535_54
# Event index 9 is out of range for TPC 0, Plane front_induction.
# Processing TPC 0, Plane middle_induction in folder 81858535_54
# Event index 9 is out of range for TPC 0, Plane middle_induction.
# Processing TPC 1, Plane front_induction in folder 81858535_54
# Processing TPC 1, Plane middle_induction in folder 81858535_54
# Processing TPC 2, Plane front_induction in folder 81858535_54
# Processing TPC 2, Plane middle_induction in folder 81858535_54
# Processing TPC 3, Plane front_induction in folder 81858535_54
# Processing TPC 3, Plane middle_induction in folder 81858535_54
# Processing TPC 0, Plane front_induction in folder 81858535_88
# Processing TPC 0, Plane middle_induction in folder 81858535_88
# Processing TPC 1, Plane front_induction in folder 81858535_88
# Processing TPC 1, Plane middle_induction in folder 81858535_88
# Processing TPC 2, Plane front_induction in folder 81858535_88
# Processing TPC 2, Plane middle_induction in folder 81858535_88
# Processing TPC 3, Plane front_induction in folder 81858535_88
# Processing TPC 3, Plane middle_induction in folder 81858535_88
# Processing TPC 0, Plane front_induction in folder 81858535_47
# Processing TPC 0, Plane middle_induction in folder 81858535_47
# Processing TPC 1, Plane front_induction in folder 81858535_47
# Processing TPC 1, Plane middle_induction in folder 81858535_47
# Processing TPC 2, Plane front_induction in folder 81858535_47
# Processing TPC 2, Plane middle_induction in folder 81858535_47
# Processing TPC 3, Plane front_induction in folder 81858535_47
# Processing TPC 3, Plane middle_induction in folder 81858535_47
# Processing TPC 0, Plane front_induction in folder 81858535_43
# Processing TPC 0, Plane middle_induction in folder 81858535_43
# Processing TPC 1, Plane front_induction in folder 81858535_43
# Processing TPC 1, Plane middle_induction in folder 81858535_43
# Processing TPC 2, Plane front_induction in folder 81858535_43
# Processing TPC 2, Plane middle_induction in folder 81858535_43
# Processing TPC 3, Plane front_induction in folder 81858535_43
# Processing TPC 3, Plane middle_induction in folder 81858535_43
# Processing TPC 0, Plane front_induction in folder 81858535_96
# Processing TPC 0, Plane middle_induction in folder 81858535_96
# Processing TPC 1, Plane front_induction in folder 81858535_96
# Processing TPC 1, Plane middle_induction in folder 81858535_96
# Processing TPC 2, Plane front_induction in folder 81858535_96
# Processing TPC 2, Plane middle_induction in folder 81858535_96
# Processing TPC 3, Plane front_induction in folder 81858535_96
# Processing TPC 3, Plane middle_induction in folder 81858535_96
# Processing TPC 0, Plane front_induction in folder 81858535_89
# Processing TPC 0, Plane middle_induction in folder 81858535_89
# Processing TPC 1, Plane front_induction in folder 81858535_89
# Processing TPC 1, Plane middle_induction in folder 81858535_89
# Processing TPC 2, Plane front_induction in folder 81858535_89
# Processing TPC 2, Plane middle_induction in folder 81858535_89
# Processing TPC 3, Plane front_induction in folder 81858535_89
# Processing TPC 3, Plane middle_induction in folder 81858535_89
# Processing TPC 0, Plane front_induction in folder 81858535_36
# Processing TPC 0, Plane middle_induction in folder 81858535_36
# Processing TPC 1, Plane front_induction in folder 81858535_36
# Processing TPC 1, Plane middle_induction in folder 81858535_36
# Processing TPC 2, Plane front_induction in folder 81858535_36
# Processing TPC 2, Plane middle_induction in folder 81858535_36
# Processing TPC 3, Plane front_induction in folder 81858535_36
# Processing TPC 3, Plane middle_induction in folder 81858535_36
# Processing TPC 0, Plane front_induction in folder 81858535_17
# Processing TPC 0, Plane middle_induction in folder 81858535_17
# Processing TPC 1, Plane front_induction in folder 81858535_17
# Processing TPC 1, Plane middle_induction in folder 81858535_17
# Processing TPC 2, Plane front_induction in folder 81858535_17
# Processing TPC 2, Plane middle_induction in folder 81858535_17
# Processing TPC 3, Plane front_induction in folder 81858535_17
# Processing TPC 3, Plane middle_induction in folder 81858535_17
# Processing TPC 0, Plane front_induction in folder 81858535_53
# Processing TPC 0, Plane middle_induction in folder 81858535_53
# Processing TPC 1, Plane front_induction in folder 81858535_53
# Processing TPC 1, Plane middle_induction in folder 81858535_53
# Processing TPC 2, Plane front_induction in folder 81858535_53
# Processing TPC 2, Plane middle_induction in folder 81858535_53
# Processing TPC 3, Plane front_induction in folder 81858535_53
# Processing TPC 3, Plane middle_induction in folder 81858535_53
# Processing TPC 0, Plane front_induction in folder 81858535_9
# Processing TPC 0, Plane middle_induction in folder 81858535_9
# Processing TPC 1, Plane front_induction in folder 81858535_9
# Processing TPC 1, Plane middle_induction in folder 81858535_9
# Processing TPC 2, Plane front_induction in folder 81858535_9
# Processing TPC 2, Plane middle_induction in folder 81858535_9
# Processing TPC 3, Plane front_induction in folder 81858535_9
# Processing TPC 3, Plane middle_induction in folder 81858535_9
# Processing TPC 0, Plane front_induction in folder 81858535_90
# Processing TPC 0, Plane middle_induction in folder 81858535_90
# Processing TPC 1, Plane front_induction in folder 81858535_90
# Processing TPC 1, Plane middle_induction in folder 81858535_90
# Processing TPC 2, Plane front_induction in folder 81858535_90
# Processing TPC 2, Plane middle_induction in folder 81858535_90
# Processing TPC 3, Plane front_induction in folder 81858535_90
# Processing TPC 3, Plane middle_induction in folder 81858535_90
# Processing TPC 0, Plane front_induction in folder 81858535_56
# Processing TPC 0, Plane middle_induction in folder 81858535_56
# Processing TPC 1, Plane front_induction in folder 81858535_56
# Processing TPC 1, Plane middle_induction in folder 81858535_56
# Processing TPC 2, Plane front_induction in folder 81858535_56
# Processing TPC 2, Plane middle_induction in folder 81858535_56
# Processing TPC 3, Plane front_induction in folder 81858535_56
# Processing TPC 3, Plane middle_induction in folder 81858535_56
# Processing TPC 0, Plane front_induction in folder 81858535_38
# Processing TPC 0, Plane middle_induction in folder 81858535_38
# Processing TPC 1, Plane front_induction in folder 81858535_38
# Processing TPC 1, Plane middle_induction in folder 81858535_38
# Processing TPC 2, Plane front_induction in folder 81858535_38
# Processing TPC 2, Plane middle_induction in folder 81858535_38
# Processing TPC 3, Plane front_induction in folder 81858535_38
# Processing TPC 3, Plane middle_induction in folder 81858535_38
# Processing TPC 0, Plane front_induction in folder 81858535_91
# Processing TPC 0, Plane middle_induction in folder 81858535_91
# Processing TPC 1, Plane front_induction in folder 81858535_91
# Processing TPC 1, Plane middle_induction in folder 81858535_91
# Processing TPC 2, Plane front_induction in folder 81858535_91
# Processing TPC 2, Plane middle_induction in folder 81858535_91
# Processing TPC 3, Plane front_induction in folder 81858535_91
# Processing TPC 3, Plane middle_induction in folder 81858535_91
# Files for TPC 0, Plane front_induction not found in folder 81858535_0.
# Files for TPC 0, Plane middle_induction not found in folder 81858535_0.
# Files for TPC 1, Plane front_induction not found in folder 81858535_0.
# Files for TPC 1, Plane middle_induction not found in folder 81858535_0.
# Files for TPC 2, Plane front_induction not found in folder 81858535_0.
# Files for TPC 2, Plane middle_induction not found in folder 81858535_0.
# Files for TPC 3, Plane front_induction not found in folder 81858535_0.
# Files for TPC 3, Plane middle_induction not found in folder 81858535_0.
# Processing TPC 0, Plane front_induction in folder 81858535_66
# Processing TPC 0, Plane middle_induction in folder 81858535_66
# Processing TPC 1, Plane front_induction in folder 81858535_66
# Processing TPC 1, Plane middle_induction in folder 81858535_66
# Processing TPC 2, Plane front_induction in folder 81858535_66
# Processing TPC 2, Plane middle_induction in folder 81858535_66
# Processing TPC 3, Plane front_induction in folder 81858535_66
# Processing TPC 3, Plane middle_induction in folder 81858535_66
# Processing TPC 0, Plane front_induction in folder 81858535_3
# Processing TPC 0, Plane middle_induction in folder 81858535_3
# Processing TPC 1, Plane front_induction in folder 81858535_3
# Processing TPC 1, Plane middle_induction in folder 81858535_3
# Processing TPC 2, Plane front_induction in folder 81858535_3
# Processing TPC 2, Plane middle_induction in folder 81858535_3
# Processing TPC 3, Plane front_induction in folder 81858535_3
# Event index 9 is out of range for TPC 3, Plane front_induction.
# Processing TPC 3, Plane middle_induction in folder 81858535_3
# Event index 9 is out of range for TPC 3, Plane middle_induction.
# Processing TPC 0, Plane front_induction in folder 81858535_26
# Processing TPC 0, Plane middle_induction in folder 81858535_26
# Processing TPC 1, Plane front_induction in folder 81858535_26
# Processing TPC 1, Plane middle_induction in folder 81858535_26
# Processing TPC 2, Plane front_induction in folder 81858535_26
# Processing TPC 2, Plane middle_induction in folder 81858535_26
# Processing TPC 3, Plane front_induction in folder 81858535_26
# Processing TPC 3, Plane middle_induction in folder 81858535_26
# Processing TPC 0, Plane front_induction in folder 81858535_64
# Processing TPC 0, Plane middle_induction in folder 81858535_64
# Processing TPC 1, Plane front_induction in folder 81858535_64
# Processing TPC 1, Plane middle_induction in folder 81858535_64
# Processing TPC 2, Plane front_induction in folder 81858535_64
# Processing TPC 2, Plane middle_induction in folder 81858535_64
# Processing TPC 3, Plane front_induction in folder 81858535_64
# Processing TPC 3, Plane middle_induction in folder 81858535_64
# Processing TPC 0, Plane front_induction in folder 81858535_61
# Processing TPC 0, Plane middle_induction in folder 81858535_61
# Processing TPC 1, Plane front_induction in folder 81858535_61
# Processing TPC 1, Plane middle_induction in folder 81858535_61
# Processing TPC 2, Plane front_induction in folder 81858535_61
# Processing TPC 2, Plane middle_induction in folder 81858535_61
# Processing TPC 3, Plane front_induction in folder 81858535_61
# Processing TPC 3, Plane middle_induction in folder 81858535_61
# Processing TPC 0, Plane front_induction in folder 81858535_95
# Processing TPC 0, Plane middle_induction in folder 81858535_95
# Processing TPC 1, Plane front_induction in folder 81858535_95
# Processing TPC 1, Plane middle_induction in folder 81858535_95
# Processing TPC 2, Plane front_induction in folder 81858535_95
# Processing TPC 2, Plane middle_induction in folder 81858535_95
# Processing TPC 3, Plane front_induction in folder 81858535_95
# Processing TPC 3, Plane middle_induction in folder 81858535_95
# Processing TPC 0, Plane front_induction in folder 81858535_31
# Processing TPC 0, Plane middle_induction in folder 81858535_31
# Processing TPC 1, Plane front_induction in folder 81858535_31
# Processing TPC 1, Plane middle_induction in folder 81858535_31
# Processing TPC 2, Plane front_induction in folder 81858535_31
# Event index 9 is out of range for TPC 2, Plane front_induction.
# Processing TPC 2, Plane middle_induction in folder 81858535_31
# Event index 9 is out of range for TPC 2, Plane middle_induction.
# Processing TPC 3, Plane front_induction in folder 81858535_31
# Processing TPC 3, Plane middle_induction in folder 81858535_31
# Processing TPC 0, Plane front_induction in folder 81858535_13
# Processing TPC 0, Plane middle_induction in folder 81858535_13
# Processing TPC 1, Plane front_induction in folder 81858535_13
# Processing TPC 1, Plane middle_induction in folder 81858535_13
# Processing TPC 2, Plane front_induction in folder 81858535_13
# Processing TPC 2, Plane middle_induction in folder 81858535_13
# Processing TPC 3, Plane front_induction in folder 81858535_13
# Processing TPC 3, Plane middle_induction in folder 81858535_13
# Processing TPC 0, Plane front_induction in folder 81858535_12
# Event index 9 is out of range for TPC 0, Plane front_induction.
# Processing TPC 0, Plane middle_induction in folder 81858535_12
# Event index 9 is out of range for TPC 0, Plane middle_induction.
# Processing TPC 1, Plane front_induction in folder 81858535_12
# Event index 9 is out of range for TPC 1, Plane front_induction.
# Processing TPC 1, Plane middle_induction in folder 81858535_12
# Event index 9 is out of range for TPC 1, Plane middle_induction.
# Processing TPC 2, Plane front_induction in folder 81858535_12
# Processing TPC 2, Plane middle_induction in folder 81858535_12
# Processing TPC 3, Plane front_induction in folder 81858535_12
# Processing TPC 3, Plane middle_induction in folder 81858535_12
# Processing TPC 0, Plane front_induction in folder 81858535_60
# Processing TPC 0, Plane middle_induction in folder 81858535_60
# Processing TPC 1, Plane front_induction in folder 81858535_60
# Processing TPC 1, Plane middle_induction in folder 81858535_60
# Processing TPC 2, Plane front_induction in folder 81858535_60
# Processing TPC 2, Plane middle_induction in folder 81858535_60
# Processing TPC 3, Plane front_induction in folder 81858535_60
# Processing TPC 3, Plane middle_induction in folder 81858535_60
# Processing TPC 0, Plane front_induction in folder 81858535_28
# Processing TPC 0, Plane middle_induction in folder 81858535_28
# Processing TPC 1, Plane front_induction in folder 81858535_28
# Processing TPC 1, Plane middle_induction in folder 81858535_28
# Processing TPC 2, Plane front_induction in folder 81858535_28
# Processing TPC 2, Plane middle_induction in folder 81858535_28
# Processing TPC 3, Plane front_induction in folder 81858535_28
# Processing TPC 3, Plane middle_induction in folder 81858535_28
# Processing TPC 0, Plane front_induction in folder 81858535_67
# Processing TPC 0, Plane middle_induction in folder 81858535_67
# Processing TPC 1, Plane front_induction in folder 81858535_67
# Processing TPC 1, Plane middle_induction in folder 81858535_67
# Processing TPC 2, Plane front_induction in folder 81858535_67
# Processing TPC 2, Plane middle_induction in folder 81858535_67
# Processing TPC 3, Plane front_induction in folder 81858535_67
# Processing TPC 3, Plane middle_induction in folder 81858535_67
# Processing TPC 0, Plane front_induction in folder 81858535_63
# Processing TPC 0, Plane middle_induction in folder 81858535_63
# Processing TPC 1, Plane front_induction in folder 81858535_63
# Processing TPC 1, Plane middle_induction in folder 81858535_63
# Processing TPC 2, Plane front_induction in folder 81858535_63
# Processing TPC 2, Plane middle_induction in folder 81858535_63
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 116
#     110 data_dict = {
#     111     "DepoSplat": true_data,
#     112     "LooseLF": rec_data_looseLf,
#     113     "MP3ROI": rec_data_mp3
#     114 }
# --> 116 predicted_image = model_selection(rec_file_path, "U" if plane_suffix == "0" else "V")
#     118 plot_data(tpc, plane, plane_suffix, data_dict, event_to_plot, predicted_image, pdf)
#
# Cell In[1], line 57, in model_selection(file_path, plane)
#      55     img = h5u.get_hwc_img(file_path, event_to_plot, ['frame_looseLf', 'frame_mp3ROI'], [1, 8], [0, 5600], [0, 4096], 2000)
# ---> 57 predicted_mask = predict_img(net=net, full_img=img, scale_factor=0.5, out_threshold=0.5, use_gpu=False)
#      58 return np.transpose(predicted_mask)
#
# Cell In[1], line 42, in predict_img(net, full_img, scale_factor, out_threshold, use_gpu)
#      41     input = img_tensor.unsqueeze(0)
# ---> 42     full_mask = net(input).squeeze().cpu().numpy()
#      44 if out_threshold < 0:
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#
# File ~/wirecell_icarus/Pytorch-UNet/unet/model.py:22, in UNet.forward(self, x)
#      21 def forward(self, x):
# ---> 22     x1 = self.inc(x)
#      23     x2 = self.down1(x1)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#
# File ~/wirecell_icarus/Pytorch-UNet/unet/parts.py:32, in inconv.forward(self, x)
#      31 def forward(self, x):
# ---> 32     x = self.conv(x)
#      33     return x
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#
# File ~/wirecell_icarus/Pytorch-UNet/unet/parts.py:22, in double_conv.forward(self, x)
#      21 def forward(self, x):
# ---> 22     x = self.conv(x)
#      23     return x
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     216 for module in self:
# --> 217     input = module(input)
#     218 return input
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/conv.py:463, in Conv2d.forward(self, input)
#     462 def forward(self, input: Tensor) -> Tensor:
# --> 463     return self._conv_forward(input, self.weight, self.bias)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/conv.py:459, in Conv2d._conv_forward(self, input, weight, bias)
#     456     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     457                     weight, bias, self.stride,
#     458                     _pair(0), self.dilation, self.groups)
# --> 459 return F.conv2d(input, weight, bias, self.stride,
#     460                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/PIL/ImageFile.py:547, in _save(im, fp, tile, bufsize)
#     546 try:
# --> 547     fh = fp.fileno()
#     548     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 89
#      86     plt.close()
#      88 # Iterate through all subdirectories in the main folder
# ---> 89 with PdfPages("ICARUS_images.pdf") as pdf:
#      90     for folder_name in os.listdir(main_folder):
#      91         folder_path = os.path.join(main_folder, folder_name)
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:2708, in PdfPages.__exit__(self, exc_type, exc_val, exc_tb)
#    2707 def __exit__(self, exc_type, exc_val, exc_tb):
# -> 2708     self.close()
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:2721, in PdfPages.close(self)
#    2716 """
#    2717 Finalize this object, making the underlying file a complete
#    2718 PDF file.
#    2719 """
#    2720 if self._file is not None:
# -> 2721     self._file.finalize()
#    2722     self._file.close()
#    2723     self._file = None
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:843, in PdfFile.finalize(self)
#     841     xobjects[name] = ob
#     842 self.writeObject(self.XObjectObject, xobjects)
# --> 843 self.writeImages()
#     844 self.writeMarkers()
#     845 self.writePathCollectionTemplates()
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1793, in PdfFile.writeImages(self)
#    1791 else:
#    1792     smaskObject = None
# -> 1793 self._writeImg(data, ob.id, smaskObject)
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1760, in PdfFile._writeImg(self, data, id, smask)
#    1758 img = Image.fromarray(rgb8, mode='P')
#    1759 img.putpalette(palette)
# -> 1760 png_data, bit_depth, palette = self._writePng(img)
#    1761 if bit_depth is None or palette is None:
#    1762     raise RuntimeError("invalid PNG header")
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1699, in PdfFile._writePng(self, img)
#    1694 """
#    1695 Write the image *img* into the pdf file using png
#    1696 predictors with Flate compression.
#    1697 """
#    1698 buffer = BytesIO()
# -> 1699 img.save(buffer, format="png")
#    1700 buffer.seek(8)
#    1701 png_data = b''
#
# File /opt/conda/lib/python3.10/site-packages/PIL/Image.py:2568, in Image.save(self, fp, format, **params)
#    2565     fp = cast(IO[bytes], fp)
#    2567 try:
# -> 2568     save_handler(self, fp, filename)
#    2569 except Exception:
#    2570     if open_fp:
#
# File /opt/conda/lib/python3.10/site-packages/PIL/PngImagePlugin.py:1431, in _save(im, fp, filename, chunk, save_all)
#    1427     im = _write_multiple_frames(
#    1428         im, fp, chunk, mode, rawmode, default_image, append_images
#    1429     )
#    1430 if im:
# -> 1431     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#    1433 if info:
#    1434     for info_chunk in info.chunks:
#
# File /opt/conda/lib/python3.10/site-packages/PIL/ImageFile.py:551, in _save(im, fp, tile, bufsize)
#     549     _encode_tile(im, fp, tile, bufsize, fh)
#     550 except (AttributeError, io.UnsupportedOperation) as exc:
# --> 551     _encode_tile(im, fp, tile, bufsize, None, exc)
#     552 if hasattr(fp, "flush"):
#     553     fp.flush()
#
# File /opt/conda/lib/python3.10/site-packages/PIL/ImageFile.py:570, in _encode_tile(im, fp, tile, bufsize, fh, exc)
#     567 if exc:
#     568     # compress to Python file-compatible object
#     569     while True:
# --> 570         errcode, data = encoder.encode(bufsize)[1:]
#     571         fp.write(data)
#     572         if errcode:
#
# KeyboardInterrupt:
