# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import os
from matplotlib.backends.backend_pdf import PdfPages  # Import PdfPages for saving to a PDF
import torch

# Import the predict_img function and models from the previous script
from unet import UNet
from utils import hwc_to_chw, h5_utils as h5u

# Path to the folder containing the output files
output_folder = '/exp/sbnd/data/users/abhat/wirecell_data/dnn_roi/ICARUS/81858535_72/'  # Change this to your output folder
pdf_filename = "81858535_72_images.pdf"  # Name of the output PDF should be similar to the last folder path above

# Define TPCs and planes
tpcs=[0,1,2,3]
tpcs=[0]
planes = ['front_induction', 'middle_induction']
plane_suffix_map = {'front_induction': '0', 'middle_induction': '1'}
planes = ['front_induction']
plane_suffix_map = {'front_induction': '0'}

# Specify which event to plot (index 0 to 9)
event_to_plot = 9  # Change this to the event index you want to plot

# Load U and V Plane models
# model_u_path = '/scratch/7DayLifetime/abhat/wirecell/dnn_roi_icarus/training/bnb_cosmics/UNet/U_Plane/best_loss.pth'
# model_v_path = '/scratch/7DayLifetime/abhat/wirecell/dnn_roi_icarus/training/bnb_cosmics/UNet/V_Plane/best_loss.pth'

model_u_path = '/scratch/7DayLifetime/abhat/wirecell/dnn_roi_icarus/training/bnb_cosmics/UNet/U_Plane/09182024/best_loss.pth'
model_v_path = '/scratch/7DayLifetime/abhat/wirecell/dnn_roi_icarus/training/bnb_cosmics/UNet/V_Plane/09182024/best_loss.pth'

net_u = UNet(2, 1)
net_u.load_state_dict(torch.load(model_u_path, map_location='cpu'))
net_u.eval()

net_v = UNet(2, 1)
net_v.load_state_dict(torch.load(model_v_path, map_location='cpu'))
net_v.eval()


def predict_img(net, full_img, scale_factor=0.5, out_threshold=0.5, use_gpu=False):
    img_tensor = torch.from_numpy(hwc_to_chw(full_img))
    if use_gpu:
        img_tensor = img_tensor.cuda()

    with torch.no_grad():
        input = img_tensor.unsqueeze(0)
        full_mask = net(input).squeeze().cpu().numpy()

    if out_threshold < 0:
        return full_mask

    return full_mask > out_threshold

def model_selection(file_path, plane):
    if plane == "U":
        net = net_u
        img = h5u.get_hwc_img(file_path, event_to_plot, ['frame_looseLf', 'frame_mp3ROI'], [1, 8], [0, 2112], [0, 4096], 2000)
    elif plane == "V":
        net = net_v
        img = h5u.get_hwc_img(file_path, event_to_plot, ['frame_looseLf', 'frame_mp3ROI'], [1, 8], [0, 5600], [0, 4096], 2000)
        # img = h5u.get_hwc_img(file_path, event_to_plot, ['frame_looseLf', 'frame_mp3ROI'], [1, 8], [1300, 2200], [2600, 3200], 2000)

    # Make the prediction
    predicted_mask = predict_img(net=net, full_img=img, scale_factor=0.5, out_threshold=0.5, use_gpu=False)
    return np.transpose(predicted_mask)

# Define the function to plot the data for each TPC and plane
def plot_data(tpc, plane, plane_suffix, data_dict, event_idx, predicted_image, pdf):
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))  # Adjust grid to fit only 4 images (DepoSplat, LooseLF, MP3 -> MP2, Predicted)
    titles = ["DepoSplat", "LooseLF", "MP3ROI", "Predicted"]

    # Plot DepoSplat, LooseLF, and MP3 as MP2
    for i, (key, data) in enumerate(data_dict.items()):
        if np.any(data) and i < 2:  # Only plot DepoSplat and LooseLF here
            ax = axes[i//2, i%2]
            ax.imshow(data, aspect='auto', cmap="bwr", vmin=-1000, vmax=1000, origin='lower')
            ax.set_title(f"{titles[i]} TPC{tpc} Plane{plane_suffix} (Event {event_idx})")
            ax.set_xlabel("Channels")
            ax.set_ylabel("Ticks")
            ax.set_xlim(1200,1400)
            ax.set_ylim(2500,3500)


    # Plot MP3 image in place of MP2
    ax = axes[1, 0]
    ax.imshow(data_dict["MP3ROI"], aspect='auto', cmap="bwr", vmin=-1000, vmax=1000, origin='lower')
    ax.set_title(f"MP3ROI TPC{tpc} Plane{plane_suffix} (Event {event_idx})")
    ax.set_xlabel("Channels")
    ax.set_ylabel("Ticks")
    ax.set_xlim(1200,1400)
    ax.set_ylim(2500,3500)

    # Plot the predicted image
    ax = axes[1, 1]  # Place in the next available subplot
    ax.imshow(predicted_image, aspect='auto', cmap="bwr", origin='lower')
    ax.set_title(f"Predicted Image TPC{tpc} Plane{plane_suffix} (Event {event_idx})")
    ax.set_xlabel("Channels")
    ax.set_ylabel("Ticks")
    ax.set_xlim(150,177.5)
    ax.set_ylim(312.5,437.5)
    # ax.invert_yaxis()



    plt.tight_layout()
    pdf.savefig(fig)  # Save the figure to the PDF
    plt.close()  # Close the figure after saving to avoid displaying it inline

# Inspect each file for each TPC and plane and save all images to a single PDF
with PdfPages(pdf_filename) as pdf:  # Open the PDF file to save the images
    for tpc in tpcs:
        for plane, plane_suffix in plane_suffix_map.items():
            # Construct file paths
            true_file_path = os.path.join(output_folder, f"tpc{tpc}_plane{plane_suffix}_tru.h5")
            rec_file_path = os.path.join(output_folder, f"tpc{tpc}_plane{plane_suffix}_rec.h5")

            if os.path.exists(true_file_path) and os.path.exists(rec_file_path):
                print(f"Opening files for TPC {tpc}, Plane {plane}:")
                print(f"True file: {true_file_path}")
                print(f"Reconstructed file: {rec_file_path}")

                # Open the files
                with h5py.File(true_file_path, 'r') as true_file, h5py.File(rec_file_path, 'r') as rec_file:
                    # Ensure the event_to_plot exists in the file
                    events = list(true_file.keys())
                    if 0 <= event_to_plot < len(events):
                        event = events[event_to_plot]
                        print(f"Processing event {event} for TPC {tpc}, Plane {plane}...")

                        # Load data for the specified event
                        true_data = true_file[event]['frame_deposplat'][:]
                        rec_data_looseLf = rec_file[event]['frame_looseLf'][:]
                        rec_data_mp3 = rec_file[event]['frame_mp3ROI'][:]  # Using MP3 in place of MP2

                        # Prepare data to plot (no MP2, MP3 in place)
                        data_dict = {
                            "DepoSplat": true_data,
                            "LooseLF": rec_data_looseLf,
                            "MP3ROI": rec_data_mp3
                        }

                        # Generate the predicted image
                        predicted_image = model_selection(rec_file_path, "U" if plane_suffix == "0" else "V")

                        # Plot the data for the specified event and predicted image, and save to the PDF
                        plot_data(tpc, plane, plane_suffix, data_dict, event_to_plot, predicted_image, pdf)
                    else:
                        print(f"Event index {event_to_plot} is out of range for TPC {tpc}, Plane {plane}.")

            else:
                print(f"Files for TPC {tpc}, Plane {plane} not found.")

print(f"All images have been saved to {pdf_filename}.")
# Out:
# /tmp/ipykernel_115633/241177171.py:35: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   net_u.load_state_dict(torch.load(model_u_path, map_location='cpu'))
# ...

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import os
from matplotlib.backends.backend_pdf import PdfPages  # Import PdfPages for saving to a PDF
import torch

# Import the predict_img function and models from the previous script
from unet import UNet
from utils import hwc_to_chw, h5_utils as h5u

# Path to the folder containing the output files
output_folder = '/exp/sbnd/data/users/abhat/wirecell_data/dnn_roi/ICARUS/optfilter-nomMC/14667123_89/'  # Change this to your output folder
pdf_filename = "14667123_89_images.pdf"  # Name of the output PDF should be similar to the last folder path above

# Define TPCs and planes
tpcs=[0,1,2,3]
tpcs=[0]
planes = ['front_induction', 'middle_induction']
plane_suffix_map = {'front_induction': '0', 'middle_induction': '1'}
planes = ['front_induction']
plane_suffix_map = {'front_induction': '0'}

# Specify which event to plot (index 0 to 9)
event_to_plot = 7  # Change this to the event index you want to plot

# Load U and V Plane models
model_u_path = '/scratch/7DayLifetime/abhat/wirecell/dnn_roi_icarus/training/bnb_cosmics/UNet/U_Plane/09182024/best_loss.pth'
model_v_path = '/scratch/7DayLifetime/abhat/wirecell/dnn_roi_icarus/training/bnb_cosmics/UNet/V_Plane/09182024/best_loss.pth'

net_u = UNet(2, 1)
net_u.load_state_dict(torch.load(model_u_path, map_location='cpu'))
net_u.eval()

net_v = UNet(2, 1)
net_v.load_state_dict(torch.load(model_v_path, map_location='cpu'))
net_v.eval()

def predict_img(net, full_img, scale_factor=0.5, out_threshold=0.5, use_gpu=False):
    img_tensor = torch.from_numpy(hwc_to_chw(full_img))
    if use_gpu:
        img_tensor = img_tensor.cuda()

    with torch.no_grad():
        input = img_tensor.unsqueeze(0)
        full_mask = net(input).squeeze().cpu().numpy()

    if out_threshold < 0:
        return full_mask

    return full_mask > out_threshold

def model_selection(file_path, plane):
    if plane == "U":
        net = net_u
        img = h5u.get_hwc_img(file_path, event_to_plot, ['frame_looseLf', 'frame_mp3ROI'], [1, 8], [0, 2112], [0, 4096], 2000)
    elif plane == "V":
        net = net_v
        img = h5u.get_hwc_img(file_path, event_to_plot, ['frame_looseLf', 'frame_mp3ROI'], [1, 8], [0, 5600], [0, 4096], 2000)

    # Make the prediction
    predicted_mask = predict_img(net=net, full_img=img, scale_factor=0.5, out_threshold=0.5, use_gpu=False)
    return np.transpose(predicted_mask)


# Define the function to plot the data for each TPC and plane
def plot_data(tpc, plane, plane_suffix, data_dict, event_idx, predicted_image, pdf):
    fig, axes = plt.subplots(3, 2, figsize=(15, 15))  # Adjust grid to fit 6 images
    titles = ["DepoSplat", "LooseLF", "MP2ROI", "MP3ROI", "Gauss", "MP2"]  # Corrected order

    # Plot DepoSplat, LooseLF, MP3ROI, Predicted, MP2, and Gauss frames
    for i, (key, data) in enumerate(data_dict.items()):
        if np.any(data):  # Only plot if data exists
            ax = axes[i//2, i%2]
            ax.imshow(data, aspect='auto', cmap="bwr", vmin=-1000, vmax=1000, origin='lower')
            ax.set_title(f"{titles[i]} TPC{tpc} Plane{plane_suffix} (Event {event_idx})")
            ax.set_xlabel("Channels")
            ax.set_ylabel("Ticks")

    # Add predicted image to the plot
    ax = axes[2, 1]  # Place in the last subplot space
    ax.imshow(predicted_image, aspect='auto', cmap="bwr", origin='lower')
    ax.set_title(f"Predicted Image TPC{tpc} Plane{plane_suffix} (Event {event_idx})")
    ax.set_xlabel("Channels")
    ax.set_ylabel("Ticks")

    plt.tight_layout()
    pdf.savefig(fig)  # Save the figure to the PDF
    plt.close()  # Close the figure after saving to avoid displaying it inline

# Inspect each file for each TPC and plane and save all images to a single PDF
with PdfPages(pdf_filename) as pdf:  # Open the PDF file to save the images
    for tpc in tpcs:
        for plane, plane_suffix in plane_suffix_map.items():
            # Construct file paths
            true_file_path = os.path.join(output_folder, f"tpc{tpc}_plane{plane_suffix}_tru.h5")
            rec_file_path = os.path.join(output_folder, f"tpc{tpc}_plane{plane_suffix}_rec.h5")

            if os.path.exists(true_file_path) and os.path.exists(rec_file_path):
                print(f"Opening files for TPC {tpc}, Plane {plane}:")
                print(f"True file: {true_file_path}")
                print(f"Reconstructed file: {rec_file_path}")

                # Open the files
                with h5py.File(true_file_path, 'r') as true_file, h5py.File(rec_file_path, 'r') as rec_file:
                    # Ensure the event_to_plot exists in the file
                    events = list(true_file.keys())
                    if 0 <= event_to_plot < len(events):
                        event = events[event_to_plot]
                        print(f"Processing event {event} for TPC {tpc}, Plane {plane}...")

                        # Load data for the specified event
                        true_data = true_file[event]['frame_deposplat'][:]
                        rec_data_looseLf = rec_file[event]['frame_looseLf'][:]
                        rec_data_mp3 = rec_file[event]['frame_mp3ROI'][:]
                        rec_data_gauss = rec_file[event]['frame_gauss'][:]  # Correctly associating data
                        rec_data_mp2 = rec_file[event]['frame_mp2ROI'][:]  # Correctly associating data

                        # Prepare data to plot
                        data_dict = {
                            "DepoSplat": true_data,
                            "LooseLF": rec_data_looseLf,
                            "MP2": rec_data_mp2,
                            "MP3ROI": rec_data_mp3,
                            "Gauss": rec_data_gauss
                        }

                        # Generate the predicted image
                        predicted_image = model_selection(rec_file_path, "U" if plane_suffix == "0" else "V")

                        # Plot the data for the specified event and predicted image, and save to the PDF
                        plot_data(tpc, plane, plane_suffix, data_dict, event_to_plot, predicted_image, pdf)
                    else:
                        print(f"Event index {event_to_plot} is out of range for TPC {tpc}, Plane {plane}.")

            else:
                print(f"Files for TPC {tpc}, Plane {plane} not found.")

print(f"All images have been saved to {pdf_filename}.")

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import os
from matplotlib.backends.backend_pdf import PdfPages  # Import PdfPages for saving to a PDF
import torch

# Import the predict_img function and models from the previous script
from unet import UNet
from utils import hwc_to_chw, h5_utils as h5u

# Path to the main folder containing subdirectories
main_folder = '/exp/sbnd/data/users/abhat/wirecell_data/dnn_roi/ICARUS/'

# Define TPCs and planes
tpcs = [0, 1, 2, 3]
planes = ['front_induction', 'middle_induction']
plane_suffix_map = {'front_induction': '0', 'middle_induction': '1'}

# Specify which event to plot (index 0 to 9)
event_to_plot = 8  # Change this to the event index you want to plot

# Load U and V Plane models
model_u_path = '/scratch/7DayLifetime/abhat/wirecell/dnn_roi_icarus/training/bnb_cosmics/UNet/U_Plane/best_loss.pth'
model_v_path = '/scratch/7DayLifetime/abhat/wirecell/dnn_roi_icarus/training/bnb_cosmics/UNet/V_Plane/best_loss.pth'

net_u = UNet(2, 1)
net_u.load_state_dict(torch.load(model_u_path, map_location='cpu'))
net_u.eval()

net_v = UNet(2, 1)
net_v.load_state_dict(torch.load(model_v_path, map_location='cpu'))
net_v.eval()

def predict_img(net, full_img, scale_factor=0.5, out_threshold=0.5, use_gpu=False):
    img_tensor = torch.from_numpy(hwc_to_chw(full_img))
    if use_gpu:
        img_tensor = img_tensor.cuda()

    with torch.no_grad():
        input = img_tensor.unsqueeze(0)
        full_mask = net(input).squeeze().cpu().numpy()

    if out_threshold < 0:
        return full_mask

    return full_mask > out_threshold

def model_selection(file_path, plane):
    if plane == "U":
        net = net_u
        img = h5u.get_hwc_img(file_path, event_to_plot, ['frame_looseLf', 'frame_mp3ROI'], [1, 8], [0, 2112], [0, 4096], 2000)
    elif plane == "V":
        net = net_v
        img = h5u.get_hwc_img(file_path, event_to_plot, ['frame_looseLf', 'frame_mp3ROI'], [1, 8], [0, 5600], [0, 4096], 2000)

    predicted_mask = predict_img(net=net, full_img=img, scale_factor=0.5, out_threshold=0.5, use_gpu=False)
    return np.transpose(predicted_mask)

def plot_data(tpc, plane, plane_suffix, data_dict, event_idx, predicted_image, pdf):
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    titles = ["DepoSplat", "LooseLF", "MP3ROI", "Predicted"]

    for i, (key, data) in enumerate(data_dict.items()):
        if np.any(data) and i < 2:
            ax = axes[i//2, i%2]
            ax.imshow(data, aspect='auto', cmap="bwr", vmin=-1000, vmax=1000, origin='lower')
            ax.set_title(f"{titles[i]} TPC{tpc} Plane{plane_suffix} (Event {event_idx})")
            ax.set_xlabel("Channels")
            ax.set_ylabel("Ticks")

    ax = axes[1, 0]
    ax.imshow(data_dict["MP3ROI"], aspect='auto', cmap="bwr", vmin=-1000, vmax=1000, origin='lower')
    ax.set_title(f"MP3ROI TPC{tpc} Plane{plane_suffix} (Event {event_idx})")
    ax.set_xlabel("Channels")
    ax.set_ylabel("Ticks")

    ax = axes[1, 1]
    ax.imshow(predicted_image, aspect='auto', cmap="bwr", origin='lower')
    ax.set_title(f"Predicted Image TPC{tpc} Plane{plane_suffix} (Event {event_idx})")
    ax.set_xlabel("Channels")
    ax.set_ylabel("Ticks")

    plt.tight_layout()
    pdf.savefig(fig)
    plt.close()

# Iterate through all subdirectories in the main folder
with PdfPages("ICARUS_images.pdf") as pdf:
    for folder_name in os.listdir(main_folder):
        folder_path = os.path.join(main_folder, folder_name)
        if os.path.isdir(folder_path):  # Ensure it's a directory
            for tpc in tpcs:
                for plane, plane_suffix in plane_suffix_map.items():
                    true_file_path = os.path.join(folder_path, f"tpc{tpc}_plane{plane_suffix}_tru.h5")
                    rec_file_path = os.path.join(folder_path, f"tpc{tpc}_plane{plane_suffix}_rec.h5")

                    if os.path.exists(true_file_path) and os.path.exists(rec_file_path):
                        print(f"Processing TPC {tpc}, Plane {plane} in folder {folder_name}")

                        with h5py.File(true_file_path, 'r') as true_file, h5py.File(rec_file_path, 'r') as rec_file:
                            events = list(true_file.keys())
                            if 0 <= event_to_plot < len(events):
                                event = events[event_to_plot]

                                true_data = true_file[event]['frame_deposplat'][:]
                                rec_data_looseLf = rec_file[event]['frame_looseLf'][:]
                                rec_data_mp3 = rec_file[event]['frame_mp3ROI'][:]

                                data_dict = {
                                    "DepoSplat": true_data,
                                    "LooseLF": rec_data_looseLf,
                                    "MP3ROI": rec_data_mp3
                                }

                                predicted_image = model_selection(rec_file_path, "U" if plane_suffix == "0" else "V")

                                plot_data(tpc, plane, plane_suffix, data_dict, event_to_plot, predicted_image, pdf)
                            else:
                                print(f"Event index {event_to_plot} is out of range for TPC {tpc}, Plane {plane}.")
                    else:
                        print(f"Files for TPC {tpc}, Plane {plane} not found in folder {folder_name}.")

print("All images have been saved to a single PDF.")

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import os
from matplotlib.backends.backend_pdf import PdfPages  # Import PdfPages for saving to a PDF
import torch

# Import the predict_img function and models from the previous script
from unet import UNet
from utils import hwc_to_chw, h5_utils as h5u

# Path to the main folder containing subdirectories
main_folder = '/exp/sbnd/data/users/abhat/wirecell_data/dnn_roi/ICARUS/optfilter-nomMC/'

# Define TPCs and planes
tpcs = [0, 1, 2, 3]
planes = ['front_induction', 'middle_induction']
plane_suffix_map = {'front_induction': '0', 'middle_induction': '1'}

# Specify which event to plot (index 0 to 9)
event_to_plot = 8  # Change this to the event index you want to plot

# Load U and V Plane models
model_u_path = '/scratch/7DayLifetime/abhat/wirecell/dnn_roi_icarus/training/bnb_cosmics/UNet/U_Plane/best_loss.pth'
model_v_path = '/scratch/7DayLifetime/abhat/wirecell/dnn_roi_icarus/training/bnb_cosmics/UNet/V_Plane/best_loss.pth'

net_u = UNet(2, 1)
net_u.load_state_dict(torch.load(model_u_path, map_location='cpu'))
net_u.eval()

net_v = UNet(2, 1)
net_v.load_state_dict(torch.load(model_v_path, map_location='cpu'))
net_v.eval()

def predict_img(net, full_img, scale_factor=0.5, out_threshold=0.5, use_gpu=False):
    img_tensor = torch.from_numpy(hwc_to_chw(full_img))
    if use_gpu:
        img_tensor = img_tensor.cuda()

    with torch.no_grad():
        input = img_tensor.unsqueeze(0)
        full_mask = net(input).squeeze().cpu().numpy()

    if out_threshold < 0:
        return full_mask

    return full_mask > out_threshold

def model_selection(file_path, plane):
    if plane == "U":
        net = net_u
        img = h5u.get_hwc_img(file_path, event_to_plot, ['frame_looseLf', 'frame_mp3ROI'], [1, 8], [0, 2112], [0, 4096], 2000)
    elif plane == "V":
        net = net_v
        img = h5u.get_hwc_img(file_path, event_to_plot, ['frame_looseLf', 'frame_mp3ROI'], [1, 8], [0, 5600], [0, 4096], 2000)

    predicted_mask = predict_img(net=net, full_img=img, scale_factor=0.5, out_threshold=0.5, use_gpu=False)
    return np.transpose(predicted_mask)

def plot_data(tpc, plane, plane_suffix, data_dict, event_idx, predicted_image, pdf):
    fig, axes = plt.subplots(3, 2, figsize=(15, 15))  # Increased rows for more data
    titles = ["DepoSplat", "LooseLF", "MP3ROI", "MP2ROI", "Gauss", "Predicted"]

    for i, (key, data) in enumerate(data_dict.items()):
        if np.any(data):
            ax = axes[i//2, i%2]
            ax.imshow(data, aspect='auto', cmap="bwr", vmin=-1000, vmax=1000, origin='lower')
            ax.set_title(f"{titles[i]} TPC{tpc} Plane{plane_suffix} (Event {event_idx})")
            ax.set_xlabel("Channels")
            ax.set_ylabel("Ticks")

    # Predicted image plot
    ax = axes[2, 1]
    ax.imshow(predicted_image, aspect='auto', cmap="bwr", origin='lower')
    ax.set_title(f"Predicted Image TPC{tpc} Plane{plane_suffix} (Event {event_idx})")
    ax.set_xlabel("Channels")
    ax.set_ylabel("Ticks")

    plt.tight_layout()
    pdf.savefig(fig)
    plt.close()

# Iterate through all subdirectories in the main folder
with PdfPages("ICARUS_images_new.pdf") as pdf:
    for folder_name in os.listdir(main_folder):
        folder_path = os.path.join(main_folder, folder_name)
        if os.path.isdir(folder_path):  # Ensure it's a directory
            for tpc in tpcs:
                for plane, plane_suffix in plane_suffix_map.items():
                    true_file_path = os.path.join(folder_path, f"tpc{tpc}_plane{plane_suffix}_tru.h5")
                    rec_file_path = os.path.join(folder_path, f"tpc{tpc}_plane{plane_suffix}_rec.h5")

                    if os.path.exists(true_file_path) and os.path.exists(rec_file_path):
                        print(f"Processing TPC {tpc}, Plane {plane} in folder {folder_name}")

                        with h5py.File(true_file_path, 'r') as true_file, h5py.File(rec_file_path, 'r') as rec_file:
                            events = list(true_file.keys())
                            if 0 <= event_to_plot < len(events):
                                event = events[event_to_plot]

                                true_data = true_file[event]['frame_deposplat'][:]
                                rec_data_looseLf = rec_file[event]['frame_looseLf'][:]
                                rec_data_mp3 = rec_file[event]['frame_mp3ROI'][:]
                                rec_data_mp2 = rec_file[event]['frame_mp2ROI'][:]
                                rec_data_gauss = rec_file[event]['frame_gauss'][:]

                                data_dict = {
                                    "DepoSplat": true_data,
                                    "LooseLF": rec_data_looseLf,
                                    "MP3ROI": rec_data_mp3,
                                    "MP2ROI": rec_data_mp2,
                                    "Gauss": rec_data_gauss
                                }

                                predicted_image = model_selection(rec_file_path, "U" if plane_suffix == "0" else "V")

                                plot_data(tpc, plane, plane_suffix, data_dict, event_to_plot, predicted_image, pdf)
                            else:
                                print(f"Event index {event_to_plot} is out of range for TPC {tpc}, Plane {plane}.")
                    else:
                        print(f"Files for TPC {tpc}, Plane {plane} not found in folder {folder_name}.")

print("All images have been saved to a single PDF.")

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Define file paths and corresponding model-dataset pairs
path = "out-eval/0_800/"
files = [
    "UNet_model_nomMC_eval_nomMC_Plane0.csv",
    "UNet_model_nomMC_eval_randMC_Plane0.csv",
    "UNet_model_randMC_eval_nomMC_Plane0.csv",
    "UNet_model_randMC_eval_randMC_Plane0.csv",
    "UNet_model_nomMC_eval_nomMC_Plane1.csv",
    "UNet_model_nomMC_eval_randMC_Plane1.csv",
    "UNet_model_randMC_eval_nomMC_Plane1.csv",
    "UNet_model_randMC_eval_randMC_Plane1.csv",
]

models = ["nomMC", "randMC"]
datasets = ["nomMC", "randMC"]

# Initialize arrays to store efficiency and purity values
pixel_eff = np.zeros((len(models), len(datasets), 2))  # Last dim: 0 -> Plane 0, 1 -> Plane 1
pixel_pur = np.zeros((len(models), len(datasets), 2))
roi_eff = np.zeros((len(models), len(datasets), 2))
roi_pur = np.zeros((len(models), len(datasets), 2))

# Process each file and extract last row (average metrics)
for file in files:
    df = pd.read_csv(os.path.join(path, file), header=None)
    avg_values = df.iloc[-1, 1:].values.astype(float)  # Extract last row

    model_idx = 0 if "nomMC" in file.split("_")[2] else 1
    dataset_idx = 0 if "nomMC" in file.split("_")[4] else 1
    plane_idx = 0 if "Plane0" in file else 1

    pixel_eff[model_idx, dataset_idx, plane_idx] = avg_values[0]
    pixel_pur[model_idx, dataset_idx, plane_idx] = avg_values[1]
    roi_eff[model_idx, dataset_idx, plane_idx] = avg_values[2]
    roi_pur[model_idx, dataset_idx, plane_idx] = avg_values[3]

# Get min and max values for consistent color scaling across all plots
vmin_eff = min(pixel_eff.min(), roi_eff.min())
vmax_eff = max(pixel_eff.max(), roi_eff.max())

vmin_pur = min(pixel_pur.min(), roi_pur.min())
vmax_pur = max(pixel_pur.max(), roi_pur.max())

# Function to plot heatmaps with consistent color scale
def plot_heatmap(data, title, ax, vmin, vmax):
    cax = ax.imshow(data, cmap="viridis", aspect="auto", vmin=vmin, vmax=vmax)
    for i in range(len(models)):
        for j in range(len(datasets)):
            ax.text(j, i, f"{data[i, j]:.4f}", ha="center", va="center", color="white")
    ax.set_xticks(range(len(datasets)))
    ax.set_yticks(range(len(models)))
    ax.set_xticklabels(datasets)
    ax.set_yticklabels(models)
    ax.set_xlabel("Datasets")
    ax.set_ylabel("Models")
    ax.set_title(title)
    return cax

# Create 2x2 subplot
fig, axs = plt.subplots(2, 2, figsize=(12, 10))
fig.suptitle("Comparison of Pixel Efficiency and Pixel Purity Across Models and Data", fontsize=14)

cax1 = plot_heatmap(pixel_eff[:, :, 0], "Pixel Efficiency (Plane 0)", axs[0, 0], vmin_eff, vmax_eff)
cax2 = plot_heatmap(pixel_eff[:, :, 1], "Pixel Efficiency (Plane 1)", axs[0, 1], vmin_eff, vmax_eff)
cax3 = plot_heatmap(pixel_pur[:, :, 0], "Pixel Purity (Plane 0)", axs[1, 0], vmin_pur, vmax_pur)
cax4 = plot_heatmap(pixel_pur[:, :, 1], "Pixel Purity (Plane 1)", axs[1, 1], vmin_pur, vmax_pur)

# Adjust layout and add colorbars with the same scale
fig.colorbar(cax1, ax=axs[0, 0])
fig.colorbar(cax2, ax=axs[0, 1])
fig.colorbar(cax3, ax=axs[1, 0])
fig.colorbar(cax4, ax=axs[1, 1])

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.savefig('pixel.pdf')
plt.show()

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Define file paths and corresponding model-dataset pairs
path = "out-eval/0_800/"
files = [
    "UNet_model_nomMC_eval_nomMC_Plane0.csv",
    "UNet_model_nomMC_eval_randMC_Plane0.csv",
    "UNet_model_randMC_eval_nomMC_Plane0.csv",
    "UNet_model_randMC_eval_randMC_Plane0.csv",
    "UNet_model_nomMC_eval_nomMC_Plane1.csv",
    "UNet_model_nomMC_eval_randMC_Plane1.csv",
    "UNet_model_randMC_eval_nomMC_Plane1.csv",
    "UNet_model_randMC_eval_randMC_Plane1.csv",
]

models = ["nomMC", "randMC"]
datasets = ["nomMC", "randMC"]

# Initialize arrays to store efficiency and purity values
pixel_eff = np.zeros((len(models), len(datasets), 2))  # Last dim: 0 -> Plane 0, 1 -> Plane 1
pixel_pur = np.zeros((len(models), len(datasets), 2))
roi_eff = np.zeros((len(models), len(datasets), 2))
roi_pur = np.zeros((len(models), len(datasets), 2))

# Process each file and extract last row (average metrics)
for file in files:
    df = pd.read_csv(os.path.join(path, file), header=None)
    avg_values = df.iloc[-1, 1:].values.astype(float)  # Extract last row

    model_idx = 0 if "nomMC" in file.split("_")[2] else 1
    dataset_idx = 0 if "nomMC" in file.split("_")[4] else 1
    plane_idx = 0 if "Plane0" in file else 1

    pixel_eff[model_idx, dataset_idx, plane_idx] = avg_values[0]
    pixel_pur[model_idx, dataset_idx, plane_idx] = avg_values[1]
    roi_eff[model_idx, dataset_idx, plane_idx] = avg_values[2]
    roi_pur[model_idx, dataset_idx, plane_idx] = avg_values[3]

# Get min and max values for consistent color scaling across all plots
vmin_eff = min(pixel_eff.min(), roi_eff.min())
vmax_eff = max(pixel_eff.max(), roi_eff.max())

vmin_pur = min(pixel_pur.min(), roi_pur.min())
vmax_pur = max(pixel_pur.max(), roi_pur.max())

# Function to plot heatmaps with consistent color scale
def plot_heatmap(data, title, ax, vmin, vmax):
    cax = ax.imshow(data, cmap="viridis", aspect="auto", vmin=vmin, vmax=vmax)
    for i in range(len(models)):
        for j in range(len(datasets)):
            ax.text(j, i, f"{data[i, j]:.4f}", ha="center", va="center", color="white")
    ax.set_xticks(range(len(datasets)))
    ax.set_yticks(range(len(models)))
    ax.set_xticklabels(datasets)
    ax.set_yticklabels(models)
    ax.set_xlabel("Datasets")
    ax.set_ylabel("Models")
    ax.set_title(title)
    return cax

# Create 2x4 subplot for both Pixel and ROI metrics
fig, axs = plt.subplots(2, 4, figsize=(16, 10))
fig.suptitle("Comparison of Pixel & ROI Efficiency and Purity Across Models and Data", fontsize=14)

# Pixel Efficiency
cax1 = plot_heatmap(pixel_eff[:, :, 0], "Pixel Efficiency (Plane 0)", axs[0, 0], vmin_eff, vmax_eff)
cax2 = plot_heatmap(pixel_eff[:, :, 1], "Pixel Efficiency (Plane 1)", axs[0, 1], vmin_eff, vmax_eff)

# Pixel Purity
cax3 = plot_heatmap(pixel_pur[:, :, 0], "Pixel Purity (Plane 0)", axs[1, 0], vmin_pur, vmax_pur)
cax4 = plot_heatmap(pixel_pur[:, :, 1], "Pixel Purity (Plane 1)", axs[1, 1], vmin_pur, vmax_pur)

# ROI Efficiency
cax5 = plot_heatmap(roi_eff[:, :, 0], "ROI Efficiency (Plane 0)", axs[0, 2], vmin_eff, vmax_eff)
cax6 = plot_heatmap(roi_eff[:, :, 1], "ROI Efficiency (Plane 1)", axs[0, 3], vmin_eff, vmax_eff)

# ROI Purity
cax7 = plot_heatmap(roi_pur[:, :, 0], "ROI Purity (Plane 0)", axs[1, 2], vmin_pur, vmax_pur)
cax8 = plot_heatmap(roi_pur[:, :, 1], "ROI Purity (Plane 1)", axs[1, 3], vmin_pur, vmax_pur)

# Adjust layout and add colorbars with the same scale
fig.colorbar(cax1, ax=axs[0, 0])
fig.colorbar(cax2, ax=axs[0, 1])
fig.colorbar(cax3, ax=axs[1, 0])
fig.colorbar(cax4, ax=axs[1, 1])
fig.colorbar(cax5, ax=axs[0, 2])
fig.colorbar(cax6, ax=axs[0, 3])
fig.colorbar(cax7, ax=axs[1, 2])
fig.colorbar(cax8, ax=axs[1, 3])

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os

# Define paths and model names
base_path = "/home/abhat/wirecell_icarus/Pytorch-UNet/out-eval/merged/"
models = ["nomMC", "randMC"]
data_types = ["nomMC", "randMC"]

# Initialize matrices for pixel and ROI efficiency and purity (2 datasets instead of 3)
metrics = {
    "Pixel_Eff": [[[0] * 2 for _ in range(3)] for _ in range(2)],
    "Pixel_Pur": [[[0] * 2 for _ in range(3)] for _ in range(2)],
    "ROI_Eff": [[[0] * 2 for _ in range(3)] for _ in range(2)],
    "ROI_Pur": [[[0] * 2 for _ in range(3)] for _ in range(2)]
}

# Helper function to extract average values from CSV
def extract_values(csv_file):
    df = pd.read_csv(csv_file)
    df.columns = df.columns.str.strip()  # Remove leading/trailing spaces
    avg_row = df[df['File'] == 'Average'].iloc[0]
    
    return {
        'Trad_Pixel_Eff': float(avg_row['Trad_Pixel_Eff']),
        'Trad_Pixel_Pur': float(avg_row['Trad_Pixel_Pur']),
        'Trad_ROI_Eff': float(avg_row['Trad_ROI_Eff']),
        'Trad_ROI_Pur': float(avg_row['Trad_ROI_Pur']),
        'DNN_Pixel_Eff': float(avg_row['DNN_Pixel_Eff']),
        'DNN_Pixel_Pur': float(avg_row['DNN_Pixel_Pur']),
        'DNN_ROI_Eff': float(avg_row['DNN_ROI_Eff']),
        'DNN_ROI_Pur': float(avg_row['DNN_ROI_Pur'])
    }

# Populate matrices
for model_idx, model in enumerate(models):
    for data_idx, data in enumerate(data_types):
        for plane in [0, 1]:
            file_name = f"UNet_model_{model}_eval_{data}_Plane{plane}.csv"
            file_path = os.path.join(base_path, file_name)
            
            if os.path.exists(file_path):
                values = extract_values(file_path)
                
                # Populate for DNN
                metrics['Pixel_Eff'][plane][model_idx][data_idx] = values['DNN_Pixel_Eff']
                metrics['Pixel_Pur'][plane][model_idx][data_idx] = values['DNN_Pixel_Pur']
                metrics['ROI_Eff'][plane][model_idx][data_idx] = values['DNN_ROI_Eff']
                metrics['ROI_Pur'][plane][model_idx][data_idx] = values['DNN_ROI_Pur']
                
                # Populate for Traditional as the third row
                metrics['Pixel_Eff'][plane][2][data_idx] = values['Trad_Pixel_Eff']
                metrics['Pixel_Pur'][plane][2][data_idx] = values['Trad_Pixel_Pur']
                metrics['ROI_Eff'][plane][2][data_idx] = values['Trad_ROI_Eff']
                metrics['ROI_Pur'][plane][2][data_idx] = values['Trad_ROI_Pur']
            else:
                print(f"File not found: {file_path}")

# Calculate product of efficiency and purity for Pixel and ROI
metrics['Pixel_Product'] = [[[metrics['Pixel_Eff'][plane][i][j] * metrics['Pixel_Pur'][plane][i][j] for j in range(2)] for i in range(3)] for plane in range(2)]
metrics['ROI_Product'] = [[[metrics['ROI_Eff'][plane][i][j] * metrics['ROI_Pur'][plane][i][j] for j in range(2)] for i in range(3)] for plane in range(2)]

# Get global min and max for all efficiency, purity, and product metrics
global_min = min(
    np.min(metrics['Pixel_Eff']), np.min(metrics['Pixel_Pur']),
    np.min(metrics['ROI_Eff']), np.min(metrics['ROI_Pur']),
    np.min(metrics['Pixel_Product']), np.min(metrics['ROI_Product'])
)
global_max = max(
    np.max(metrics['Pixel_Eff']), np.max(metrics['Pixel_Pur']),
    np.max(metrics['ROI_Eff']), np.max(metrics['ROI_Pur']),
    np.max(metrics['Pixel_Product']), np.max(metrics['ROI_Product'])
)

# Plotting function using seaborn
def plot_heatmap(data, title, ax):
    sns.heatmap(data, annot=True, fmt=".4f", cmap="PRGn", cbar=True, vmin=global_min, vmax=global_max,
                xticklabels=data_types, yticklabels=models + ["Traditional"], ax=ax, annot_kws={"size": 12, "weight": 'bold'}, linewidths=.5)
    ax.set_title(title, fontsize=14, fontweight='bold')
    ax.set_xlabel("Evaluated Dataset", fontsize=12)
    ax.set_ylabel("Model", fontsize=12)

# Create subplots
fig, axes = plt.subplots(6, 2, figsize=(18, 36))

metric_titles = ["Pixel Efficiency", "Pixel Purity", "ROI Efficiency", "ROI Purity", "Pixel Efficiency × Purity", "ROI Efficiency × Purity"]
planes = ["Plane 0", "Plane 1"]

for idx, metric in enumerate(['Pixel_Eff', 'Pixel_Pur', 'ROI_Eff', 'ROI_Pur', 'Pixel_Product', 'ROI_Product']):
    for plane in [0, 1]:
        plot_heatmap(metrics[metric][plane], f"{metric_titles[idx]} ({planes[plane]})", axes[idx, plane])

fig.suptitle("Comparison of Pixel and ROI Metrics Across Models and Datasets", fontsize=18, fontweight='bold')
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig('metrics_comparison_matrix_with_product.pdf', dpi=500)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os

# Define paths and model names
base_path = "/home/abhat/wirecell_icarus/Pytorch-UNet/out-eval/merged/gauss_th0"
models = ["nomMC", "randMC"]
data_types = ["nomMC", "randMC"]

# Initialize matrices for pixel and ROI efficiency and purity (2 datasets instead of 3)
metrics = {
    "Pixel_Eff": [[[0] * 2 for _ in range(3)] for _ in range(2)],
    "Pixel_Pur": [[[0] * 2 for _ in range(3)] for _ in range(2)],
    "ROI_Eff": [[[0] * 2 for _ in range(3)] for _ in range(2)],
    "ROI_Pur": [[[0] * 2 for _ in range(3)] for _ in range(2)]
}

# Helper function to extract average values from CSV
def extract_values(csv_file):
    df = pd.read_csv(csv_file)
    df.columns = df.columns.str.strip()  # Remove leading/trailing spaces
    avg_row = df[df['File'] == 'Average'].iloc[0]
    
    return {
        'Trad_Pixel_Eff': float(avg_row['Trad_Pixel_Eff']),
        'Trad_Pixel_Pur': float(avg_row['Trad_Pixel_Pur']),
        'Trad_ROI_Eff': float(avg_row['Trad_ROI_Eff']),
        'Trad_ROI_Pur': float(avg_row['Trad_ROI_Pur']),
        'DNN_Pixel_Eff': float(avg_row['DNN_Pixel_Eff']),
        'DNN_Pixel_Pur': float(avg_row['DNN_Pixel_Pur']),
        'DNN_ROI_Eff': float(avg_row['DNN_ROI_Eff']),
        'DNN_ROI_Pur': float(avg_row['DNN_ROI_Pur'])
    }

# Populate matrices
for model_idx, model in enumerate(models):
    for data_idx, data in enumerate(data_types):
        for plane in [0, 1]:
            file_name = f"UNet_model_{model}_eval_{data}_Plane{plane}.csv"
            file_path = os.path.join(base_path, file_name)
            
            if os.path.exists(file_path):
                values = extract_values(file_path)
                
                # Populate for DNN
                metrics['Pixel_Eff'][plane][model_idx][data_idx] = values['DNN_Pixel_Eff']
                metrics['Pixel_Pur'][plane][model_idx][data_idx] = values['DNN_Pixel_Pur']
                metrics['ROI_Eff'][plane][model_idx][data_idx] = values['DNN_ROI_Eff']
                metrics['ROI_Pur'][plane][model_idx][data_idx] = values['DNN_ROI_Pur']
                
                # Populate for Traditional as the third row
                metrics['Pixel_Eff'][plane][2][data_idx] = values['Trad_Pixel_Eff']
                metrics['Pixel_Pur'][plane][2][data_idx] = values['Trad_Pixel_Pur']
                metrics['ROI_Eff'][plane][2][data_idx] = values['Trad_ROI_Eff']
                metrics['ROI_Pur'][plane][2][data_idx] = values['Trad_ROI_Pur']
            else:
                print(f"File not found: {file_path}")

# Calculate product of efficiency and purity for Pixel and ROI
metrics['Pixel_Product'] = [[[metrics['Pixel_Eff'][plane][i][j] * metrics['Pixel_Pur'][plane][i][j] for j in range(2)] for i in range(3)] for plane in range(2)]
metrics['ROI_Product'] = [[[metrics['ROI_Eff'][plane][i][j] * metrics['ROI_Pur'][plane][i][j] for j in range(2)] for i in range(3)] for plane in range(2)]

# Get global min and max for all efficiency, purity, and product metrics
global_min = min(
    np.min(metrics['Pixel_Eff']), np.min(metrics['Pixel_Pur']),
    np.min(metrics['ROI_Eff']), np.min(metrics['ROI_Pur']),
    np.min(metrics['Pixel_Product']), np.min(metrics['ROI_Product'])
)
global_max = max(
    np.max(metrics['Pixel_Eff']), np.max(metrics['Pixel_Pur']),
    np.max(metrics['ROI_Eff']), np.max(metrics['ROI_Pur']),
    np.max(metrics['Pixel_Product']), np.max(metrics['ROI_Product'])
)

# Plotting function using seaborn
def plot_heatmap(data, title, ax):
    sns.heatmap(data, annot=True, fmt=".4f", cmap="PRGn", cbar=True, vmin=global_min, vmax=global_max,
                xticklabels=data_types, yticklabels=models + ["Traditional"], ax=ax, annot_kws={"size": 12, "weight": 'bold'}, linewidths=.5)
    ax.set_title(title, fontsize=14, fontweight='bold')
    ax.set_xlabel("Evaluated Dataset", fontsize=12)
    ax.set_ylabel("Model", fontsize=12)

# Create subplots
fig, axes = plt.subplots(6, 2, figsize=(18, 36))

metric_titles = ["Pixel Efficiency", "Pixel Purity", "ROI Efficiency", "ROI Purity", "Pixel Efficiency × Purity", "ROI Efficiency × Purity"]
planes = ["Plane 0", "Plane 1"]

for idx, metric in enumerate(['Pixel_Eff', 'Pixel_Pur', 'ROI_Eff', 'ROI_Pur', 'Pixel_Product', 'ROI_Product']):
    for plane in [0, 1]:
        plot_heatmap(metrics[metric][plane], f"{metric_titles[idx]} ({planes[plane]})", axes[idx, plane])

fig.suptitle("Comparison of Pixel and ROI Metrics Across Models and Datasets", fontsize=18, fontweight='bold')
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig('metrics_comparison_matrix_with_product.pdf', dpi=500)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os

# Define paths and model names
base_path = "/home/abhat/wirecell_icarus/Pytorch-UNet/out-eval/merged/gauss_th!0"
models = ["nomMC", "randMC"]
data_types = ["nomMC", "randMC"]

# Initialize matrices for pixel and ROI efficiency and purity (2 datasets instead of 3)
metrics = {
    "Pixel_Eff": [[[0] * 2 for _ in range(3)] for _ in range(2)],
    "Pixel_Pur": [[[0] * 2 for _ in range(3)] for _ in range(2)],
    "ROI_Eff": [[[0] * 2 for _ in range(3)] for _ in range(2)],
    "ROI_Pur": [[[0] * 2 for _ in range(3)] for _ in range(2)]
}

# Helper function to extract average values from CSV
def extract_values(csv_file):
    df = pd.read_csv(csv_file)
    df.columns = df.columns.str.strip()  # Remove leading/trailing spaces
    avg_row = df[df['File'] == 'Average'].iloc[0]
    
    return {
        'Trad_Pixel_Eff': float(avg_row['Trad_Pixel_Eff']),
        'Trad_Pixel_Pur': float(avg_row['Trad_Pixel_Pur']),
        'Trad_ROI_Eff': float(avg_row['Trad_ROI_Eff']),
        'Trad_ROI_Pur': float(avg_row['Trad_ROI_Pur']),
        'DNN_Pixel_Eff': float(avg_row['DNN_Pixel_Eff']),
        'DNN_Pixel_Pur': float(avg_row['DNN_Pixel_Pur']),
        'DNN_ROI_Eff': float(avg_row['DNN_ROI_Eff']),
        'DNN_ROI_Pur': float(avg_row['DNN_ROI_Pur'])
    }

# Populate matrices
for model_idx, model in enumerate(models):
    for data_idx, data in enumerate(data_types):
        for plane in [0, 1]:
            file_name = f"UNet_model_{model}_eval_{data}_Plane{plane}.csv"
            file_path = os.path.join(base_path, file_name)
            
            if os.path.exists(file_path):
                values = extract_values(file_path)
                
                # Populate for DNN
                metrics['Pixel_Eff'][plane][model_idx][data_idx] = values['DNN_Pixel_Eff']
                metrics['Pixel_Pur'][plane][model_idx][data_idx] = values['DNN_Pixel_Pur']
                metrics['ROI_Eff'][plane][model_idx][data_idx] = values['DNN_ROI_Eff']
                metrics['ROI_Pur'][plane][model_idx][data_idx] = values['DNN_ROI_Pur']
                
                # Populate for Traditional as the third row
                metrics['Pixel_Eff'][plane][2][data_idx] = values['Trad_Pixel_Eff']
                metrics['Pixel_Pur'][plane][2][data_idx] = values['Trad_Pixel_Pur']
                metrics['ROI_Eff'][plane][2][data_idx] = values['Trad_ROI_Eff']
                metrics['ROI_Pur'][plane][2][data_idx] = values['Trad_ROI_Pur']
            else:
                print(f"File not found: {file_path}")

# Calculate product of efficiency and purity for Pixel and ROI
metrics['Pixel_Product'] = [[[metrics['Pixel_Eff'][plane][i][j] * metrics['Pixel_Pur'][plane][i][j] for j in range(2)] for i in range(3)] for plane in range(2)]
metrics['ROI_Product'] = [[[metrics['ROI_Eff'][plane][i][j] * metrics['ROI_Pur'][plane][i][j] for j in range(2)] for i in range(3)] for plane in range(2)]

# Get global min and max for all efficiency, purity, and product metrics
global_min = min(
    np.min(metrics['Pixel_Eff']), np.min(metrics['Pixel_Pur']),
    np.min(metrics['ROI_Eff']), np.min(metrics['ROI_Pur']),
    np.min(metrics['Pixel_Product']), np.min(metrics['ROI_Product'])
)
global_max = max(
    np.max(metrics['Pixel_Eff']), np.max(metrics['Pixel_Pur']),
    np.max(metrics['ROI_Eff']), np.max(metrics['ROI_Pur']),
    np.max(metrics['Pixel_Product']), np.max(metrics['ROI_Product'])
)

# Plotting function using seaborn
def plot_heatmap(data, title, ax):
    sns.heatmap(data, annot=True, fmt=".4f", cmap="PRGn", cbar=True, vmin=global_min, vmax=global_max,
                xticklabels=data_types, yticklabels=models + ["Traditional"], ax=ax, annot_kws={"size": 12, "weight": 'bold'}, linewidths=.5)
    ax.set_title(title, fontsize=14, fontweight='bold')
    ax.set_xlabel("Evaluated Dataset", fontsize=12)
    ax.set_ylabel("Model", fontsize=12)

# Create subplots
fig, axes = plt.subplots(6, 2, figsize=(18, 36))

metric_titles = ["Pixel Efficiency", "Pixel Purity", "ROI Efficiency", "ROI Purity", "Pixel Efficiency × Purity", "ROI Efficiency × Purity"]
planes = ["Plane 0", "Plane 1"]

for idx, metric in enumerate(['Pixel_Eff', 'Pixel_Pur', 'ROI_Eff', 'ROI_Pur', 'Pixel_Product', 'ROI_Product']):
    for plane in [0, 1]:
        plot_heatmap(metrics[metric][plane], f"{metric_titles[idx]} ({planes[plane]})", axes[idx, plane])

fig.suptitle("Comparison of Pixel and ROI Metrics Across Models and Datasets", fontsize=18, fontweight='bold')
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig('metrics_comparison_gaussth!0.pdf', dpi=500)
plt.show()
